# %% [markdown]
# <a href="https://colab.research.google.com/github/blakempaul/BTE320/blob/main/BTE320_Class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# This is a test

# %%
x = 2
x = 'b'
x = 3.14

# %% [markdown]
# This is another test

# %%
x = 2
x == 2
# Out:
# True

# %%
s = 'abc'

# %%
a = 3
b = 5
a == b
a < b
a <= b
a > b
a >= b
a != b
# Out:
# True

# %%
a + b
# Out:
# 8

# %%
5 + 3.0
# Out:
# 8.0

# %%
4 * 3
# Out:
# 12

# %%
6 / 4
# Out:
# 1.5

# %%
6 // 4
# Out:
# 1

# %%
6.0 // 4.0
# Out:
# 1.0

# %%
2 ** 3
# Out:
# 8

# %%
5 % 3
# Out:
# 2

# %%
6 % 3
# Out:
# 0

# %%
1 % 3
# Out:
# 1

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
x = x + 1

x += 1

# %%
name = 5
name4 = 6

4name = 7

studentLoan = ...
student_loam = ...

student loan = ...

_x = ...
_2x = ...
# Out:
#   File "/tmp/ipython-input-3842369329.py", line 4
#     4name = 7
#     ^
# SyntaxError: invalid decimal literal

# %%
type(x)
# Out:
# int

# %%
isinstance(x, (int, float, bool))
# Out:
# True

# %%
a = 3
b = 'abc'

# %%
a, b = 3, 'abc'
