# %% [markdown]
# <a href="https://colab.research.google.com/github/blakempaul/BTE320/blob/main/In_ClassAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In Class Assignment #1
#
# Gross Profit = Sales - COGS

# %%
Sales = float(input("Enter sales ($): "))
rate = float(input("Enter COGS rate (%): "))

COGS = 0.4 * Sales
gross_profit = Sales - COGS
taxes = rate * gross_profit
net = gross_profit - taxes

print(f"Sales: {Sales}$")
print(f"COGS: {COGS}$")
print(f"Gross Profit: {gross_profit}$")
# Out:
# Enter sales ($): 12000
# Enter COGS rate (%): 30
# Sales: 12000.0$
# COGS: 4800.0$
# Gross Profit: 7200.0$
